# %% [markdown]
# # ML-12 — Tell the Story
#
# **Paper (live):** https://ayush0121n.github.io/flyrank-ml-assignment/submission/
# **Repo:** https://github.com/ayush0121n/flyrank-ml-assignment
# **Lane:** CTR / Engagement Opportunity Scoring
#
# This notebook holds the **5-minute demo outline** and **two shareable cuts**. The case study itself lives inside the deployed paper (abstract + introduction).

# %% [markdown]
# ## Case-study framing (inside the paper)
#
# The FlyRank content problem this lane addresses:
#
# > Large content portfolios have many URLs that already earn impressions. A subset under-captures clicks relative to peers. Editorial time is scarce—operators need a **ranked review queue**, not a full-site rewrite list.
#
# Findings in the paper (client-holdout GB AUC 0.781 vs rule baseline 0.577) are framed as **decision-support for that queue**, in public-safe language, with no client names or private queries.

# %% [markdown]
# ## 5-minute demo outline (Week-8 showcase, optional)
#
# | Min | Beat | What you say / show |
# |-----|------|---------------------|
# | 0:00–0:45 | **Question** | “Among pages that already get impressions, which ones under-capture clicks—and can we rank them for editors better than a simple rule?” |
# | 0:45–1:45 | **Method** | May features only → June opportunity label. Client-holdout so test clients are unseen. Leakage checks: no June metrics in X. |
# | 1:45–3:00 | **One chart** | Show Figure 1 (AUC bars): baseline 0.577 vs GB **0.781**. Mention base rate ~22.6%. |
# | 3:00–4:00 | **One honest result** | “Lift over the rule baseline on held-out clients. Observational—not a causal traffic guarantee.” |
# | 4:00–5:00 | **One recommendation** | Tier-1 action: prioritize title/meta review for `LOW_CTR_MAY` + solid impressions. No auto-publish. |
#
# **Props:** live paper URL, `capstone_metrics.json`, one SVG/chart from the paper.

# %% [markdown]
# ## Shareable cut 1 — short social post (methodology)
#
# Just shipped my FlyRank ML capstone: ranking CTR *opportunity* on real search performance data.
#
# Method in one breath: prior-month GSC + content features only → next-month under-capture label → client-holdout validation (no test client in training) → Gradient Boosting **AUC 0.781** vs a simple rule baseline **0.577**.
#
# It’s a review queue for editors, not a promise that rewrites “will grow traffic.” Paper + repo linked in reply / bio.
#
# #MachineLearning #SEO #SearchAnalytics

# %% [markdown]
# ## Shareable cut 2 — employer-facing summary (3 sentences)
#
# I built a CTR / engagement opportunity model on the FlyRank internship warehouse (monthly GSC aggregates + content attributes; May features → June labels). On a client-level holdout, gradient boosting ranked under-capturing pages at ROC-AUC 0.781 versus a 0.577 rule baseline (base rate ≈ 22.6%). The deliverable is a decision-support action playbook—ranked review tiers with reason codes—not automated publishing or causal traffic claims.
#
# **Paper:** https://ayush0121n.github.io/flyrank-ml-assignment/submission/
# **Repo:** https://github.com/ayush0121n/flyrank-ml-assignment

# %%
print("ML-12 artifacts ready:")
print("  - Paper case-study framing: submission/index.html (deployed)")
print("  - Demo outline + two cuts: this notebook")
print("  - Metrics: work/outputs/capstone_metrics.json")
# Out:
# ML-12 artifacts ready:
#   - Paper case-study framing: submission/index.html (deployed)
#   - Demo outline + two cuts: this notebook
#   - Metrics: work/outputs/capstone_metrics.json

# %% [markdown]
# ## Self-check
#
# - [x] Paper abstract + intro tie findings to the FlyRank content review-queue problem
# - [x] 5-minute demo outline: question, method, one chart, one honest result, one recommendation
# - [x] Social methodology post (honest, specific)
# - [x] Employer 3-sentence summary (what / data / showed)
# - [x] Public-safe language throughout
